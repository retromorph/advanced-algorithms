# %% [markdown]
# # Источники

# %% [markdown]
# **Основные материалы**
# - Алгоритмы построение и анализ. Томас Кормен, Чарльз Лейзерсон, Рональд Ривест Клиффорд Штайн. - настоящая настольная библия по теории алгоритмов
#
# - [Алгоритмы и структуры данных пилотный поток 2021/2022](http://wiki.cs.hse.ru/%D0%90%D0%BB%D0%B3%D0%BE%D1%80%D0%B8%D1%82%D0%BC%D1%8B_%D0%B8_%D1%81%D1%82%D1%80%D1%83%D0%BA%D1%82%D1%83%D1%80%D1%8B_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85_%D0%BF%D0%B8%D0%BB%D0%BE%D1%82%D0%BD%D1%8B%D0%B9_%D0%BF%D0%BE%D1%82%D0%BE%D0%BA_2021/2022) - невероятно крутой курс по алгоритмам в вышке от лида поиска Яндекса
#
# - [Алгоритмика](https://ru.algorithmica.org) - много реализованных на C++ алгоритмов и базовое введение к ним, удобно чтобы быстро погрузиться в тему

# %% [markdown]
# **Дополнительные материалы**
#
# - Алгоритмы руководство по разработке. Стивен Скиена. - как Кормен, только проще, с реализациями алгоритмов на C++ и более практическим уклоном
#
# - Спортивное программирование. Стивен Халим, Феликс Халим. - жесткий уклон в спортпрогу, много специфических для этого раздела тем
#
# - [Вики ИТМО](https://neerc.ifmo.ru/wiki) - покрывают некоторые специфические темы
#
# - [Emaxx](http://www.e-maxx-ru.1gb.ru/algo/) - много готовых алгоритмов на C++

# %% [markdown]
# **Где решать задачи**
#
# - Алгоритмы построение и анализ. Томас Кормен, Чарльз Лейзерсон, Рональд Ривест Клиффорд Штайн. - очень много теоретических задач
#
# - [Алгоритмы и структуры данных пилотный поток 2021/2022](http://wiki.cs.hse.ru/%D0%90%D0%BB%D0%B3%D0%BE%D1%80%D0%B8%D1%82%D0%BC%D1%8B_%D0%B8_%D1%81%D1%82%D1%80%D1%83%D0%BA%D1%82%D1%83%D1%80%D1%8B_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85_%D0%BF%D0%B8%D0%BB%D0%BE%D1%82%D0%BD%D1%8B%D0%B9_%D0%BF%D0%BE%D1%82%D0%BE%D0%BA_2021/2022) - много теоретических и практических задач
#
# - [Codeforces](https://codeforces.com/;?mobile=false) - большой банк заданий и соревнования по спортпроге каждую неделю
